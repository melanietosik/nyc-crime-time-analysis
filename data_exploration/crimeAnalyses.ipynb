# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
import random
import math
# %matplotlib inline

# %%
#read in already cleaned up data
dataset = pd.read_csv("./crimeData.csv", sep = "\t", header = 0)

# %%
#aggregate locations

#number of grids on x-axis (starting at 1)
resX = 200;
#number of grids on y-axis
resY = 200;

#identify the x,y edges of the data
x_max = dataset['X_COORD_CD'].max()
x_min = dataset['X_COORD_CD'].min()
y_max = dataset['Y_COORD_CD'].max()
y_min = dataset['Y_COORD_CD'].min()

xCoordinate = dataset['X_COORD_CD']
yCoordinate = dataset['Y_COORD_CD']

#distances along x and y axis
rangeX = x_max - x_min
rangeY = y_max - y_min

#linear transformations
kX = (resX-1)/rangeX
cX = x_min*kX -1
newX = round(kX * xCoordinate - cX)
kY = (resY-1)/rangeY
cY = y_min*kY -1
newY = round(kY * yCoordinate - cY)

dataset['New_X_Coor'] = newX
dataset['New_Y_Coor'] = newY

# %%
dataset
# Out:
#          Unnamed: 0 CMPLNT_FR_DT CMPLNT_FR_TM      RPT_DT  KY_CD  \
# 0                 0   12/31/2015     23:45:00  12/31/2015    113
# 1                 1   12/31/2015     23:36:00  12/31/2015    101
# 2                 2   12/31/2015     23:30:00  12/31/2015    117
# 3                 3   12/31/2015     23:30:00  12/31/2015    344
# 4                 4   12/31/2015     23:25:00  12/31/2015    344
# 5                 5   12/31/2015     23:18:00  12/31/2015    106
# 6                 6   12/31/2015     23:15:00  12/31/2015    235
# 7                 7   12/31/2015     23:15:00  12/31/2015    118
# 8                 8   12/31/2015     23:15:00  12/31/2015    344
# 9                 9   12/31/2015     23:10:00  12/31/2015    341
# 10               10   12/31/2015     23:05:00  12/31/2015    341
# 11               11   12/31/2015     23:00:00  12/31/2015    341
# 12               12   12/31/2015     23:00:00  12/31/2015    109
# 13               13   12/31/2015     23:00:00  12/31/2015    109
# 14               14   12/31/2015     23:00:00  12/31/2015    113
# 15               15   12/31/2015     23:00:00  12/31/2015    105
# 16               16   12/31/2015     23:00:00  12/31/2015    109
# 17               17   12/31/2015     23:00:00  12/31/2015    359
# 18               18   12/31/2015     23:00:00  12/31/2015    344
# 19               19   12/31/2015     22:55:00  12/31/2015    351
# 20               20   12/31/2015     22:53:00  12/31/2015    235
# 21               22   12/31/2015     22:50:00  12/31/2015    235
# 22               23   12/31/2015     22:50:00  12/31/2015    106
# 23               24   12/31/2015     22:45:00  12/31/2015    118
# 24               25   12/31/2015     22:45:00  12/31/2015    344
# 25               26   12/31/2015     22:45:00  12/31/2015    344
# 26               27   12/31/2015     22:45:00  12/31/2015    118
# 27               28   12/31/2015     22:40:00  12/31/2015    235
# 28               29   12/31/2015     22:40:00  12/31/2015    347
# 29               30   12/31/2015     22:37:00  12/31/2015    351
# ...             ...          ...          ...         ...    ...
# 5384137     5580004   12/16/2015     11:00:00  01/01/2016    361
# 5384138     5580005   12/15/2015     15:00:00  01/01/2016    361
# 5384139     5580006   12/13/2015     23:45:00  01/01/2016    107
# 5384140     5580007   12/13/2015     11:00:00  01/01/2016    358
# 5384141     5580008   12/13/2015     05:24:00  01/01/2016    114
# 5384142     5580009   12/11/2015     09:00:00  01/01/2016    109
# 5384143     5580010   12/09/2015     12:00:00  01/01/2016    578
# 5384144     5580011   12/07/2015     16:00:00  01/01/2016    578
# 5384145     5580012   12/03/2015     18:10:00  01/01/2016    109
# 5384146     5580013   12/01/2015     07:00:00  01/01/2016    109
# 5384147     5580014   11/30/2015     00:21:00  01/01/2016    114
# 5384148     5580015   11/26/2015     17:00:00  01/01/2016    578
# 5384149     5580016   11/26/2015     17:00:00  01/01/2016    578
# 5384150     5580017   11/21/2015     17:40:00  01/01/2016    361
# 5384151     5580019   09/03/2015     21:22:00  01/01/2016    114
# 5384152     5580020   07/05/2015     12:00:00  01/01/2016    361
# 5384153     5580021   07/01/2015     12:00:00  01/01/2016    361
# 5384154     5580022   01/01/2015     23:30:00  01/01/2016    117
# 5384155     5580023   01/01/2015     22:10:00  01/01/2016    578
# 5384156     5580024   01/01/2015     09:00:00  01/01/2016    578
# 5384157     5580025   01/01/2015     07:40:00  01/01/2016    106
# 5384158     5580026   01/01/2015     06:30:00  01/01/2016    578
# 5384159     5580027   01/01/2015     04:45:00  01/01/2016    578
# 5384160     5580028   01/01/2015     04:30:00  01/01/2016    344
# 5384161     5580029   01/01/2015     04:30:00  01/01/2016    105
# 5384162     5580030   01/01/2015     03:50:00  01/01/2016    105
# 5384163     5580031   01/01/2015     01:25:00  01/01/2016    578
# 5384164     5580032   01/01/2015     00:30:00  01/01/2016    106
# 5384165     5580033   06/30/2014     12:00:00  01/01/2016    361
# 5384166     5580034   12/31/2001     16:00:00  01/01/2016    107
#
#                                OFNS_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD  \
# 0                                FORGERY        COMPLETED       FELONY
# 1        MURDER & NON-NEGL. MANSLAUGHTER        COMPLETED       FELONY
# 2                        DANGEROUS DRUGS        COMPLETED       FELONY
# 3           ASSAULT 3 & RELATED OFFENSES        COMPLETED  MISDEMEANOR
# 4           ASSAULT 3 & RELATED OFFENSES        COMPLETED  MISDEMEANOR
# 5                         FELONY ASSAULT        ATTEMPTED       FELONY
# 6                        DANGEROUS DRUGS        COMPLETED  MISDEMEANOR
# 7                      DANGEROUS WEAPONS        COMPLETED       FELONY
# 8           ASSAULT 3 & RELATED OFFENSES        COMPLETED  MISDEMEANOR
# 9                          PETIT LARCENY        COMPLETED  MISDEMEANOR
# 10                         PETIT LARCENY        COMPLETED  MISDEMEANOR
# 11                         PETIT LARCENY        COMPLETED  MISDEMEANOR
# 12                         GRAND LARCENY        COMPLETED       FELONY
# 13                         GRAND LARCENY        COMPLETED       FELONY
# 14                               FORGERY        COMPLETED       FELONY
# 15                               ROBBERY        COMPLETED       FELONY
# 16                         GRAND LARCENY        COMPLETED       FELONY
# 17        OFFENSES AGAINST PUBLIC ADMINI        COMPLETED  MISDEMEANOR
# 18          ASSAULT 3 & RELATED OFFENSES        COMPLETED  MISDEMEANOR
# 19        CRIMINAL MISCHIEF & RELATED OF        COMPLETED  MISDEMEANOR
# 20                       DANGEROUS DRUGS        COMPLETED  MISDEMEANOR
# 21                       DANGEROUS DRUGS        COMPLETED  MISDEMEANOR
# 22                        FELONY ASSAULT        COMPLETED       FELONY
# 23                     DANGEROUS WEAPONS        COMPLETED       FELONY
# 24          ASSAULT 3 & RELATED OFFENSES        COMPLETED  MISDEMEANOR
# 25          ASSAULT 3 & RELATED OFFENSES        COMPLETED  MISDEMEANOR
# 26                     DANGEROUS WEAPONS        COMPLETED       FELONY
# 27                       DANGEROUS DRUGS        COMPLETED  MISDEMEANOR
# 28        INTOXICATED & IMPAIRED DRIVING        COMPLETED  MISDEMEANOR
# 29        CRIMINAL MISCHIEF & RELATED OF        COMPLETED  MISDEMEANOR
# ...                                  ...              ...          ...
# 5384137    OFF. AGNST PUB ORD SENSBLTY &        COMPLETED  MISDEMEANOR
# 5384138    OFF. AGNST PUB ORD SENSBLTY &        COMPLETED  MISDEMEANOR
# 5384139                         BURGLARY        COMPLETED       FELONY
# 5384140         OFFENSES INVOLVING FRAUD        COMPLETED  MISDEMEANOR
# 5384141                            ARSON        COMPLETED       FELONY
# 5384142                    GRAND LARCENY        COMPLETED       FELONY
# 5384143                    HARRASSMENT 2        COMPLETED    VIOLATION
# 5384144                    HARRASSMENT 2        COMPLETED    VIOLATION
# 5384145                    GRAND LARCENY        COMPLETED       FELONY
# 5384146                    GRAND LARCENY        COMPLETED       FELONY
# 5384147                            ARSON        COMPLETED       FELONY
# 5384148                    HARRASSMENT 2        COMPLETED    VIOLATION
# 5384149                    HARRASSMENT 2        COMPLETED    VIOLATION
# 5384150    OFF. AGNST PUB ORD SENSBLTY &        COMPLETED  MISDEMEANOR
# 5384151                            ARSON        COMPLETED       FELONY
# 5384152    OFF. AGNST PUB ORD SENSBLTY &        COMPLETED  MISDEMEANOR
# 5384153    OFF. AGNST PUB ORD SENSBLTY &        COMPLETED  MISDEMEANOR
# 5384154                  DANGEROUS DRUGS        COMPLETED       FELONY
# 5384155                    HARRASSMENT 2        COMPLETED    VIOLATION
# 5384156                    HARRASSMENT 2        COMPLETED    VIOLATION
# 5384157                   FELONY ASSAULT        COMPLETED       FELONY
# 5384158                    HARRASSMENT 2        COMPLETED    VIOLATION
# 5384159                    HARRASSMENT 2        COMPLETED    VIOLATION
# 5384160     ASSAULT 3 & RELATED OFFENSES        COMPLETED  MISDEMEANOR
# 5384161                          ROBBERY        COMPLETED       FELONY
# 5384162                          ROBBERY        COMPLETED       FELONY
# 5384163                    HARRASSMENT 2        COMPLETED    VIOLATION
# 5384164                   FELONY ASSAULT        COMPLETED       FELONY
# 5384165    OFF. AGNST PUB ORD SENSBLTY &        COMPLETED  MISDEMEANOR
# 5384166                         BURGLARY        COMPLETED       FELONY
#
#                   JURIS_DESC        BORO_NM  ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# 0           N.Y. POLICE DEPT          BRONX         44.0            INSIDE
# 1           N.Y. POLICE DEPT         QUEENS        103.0           OUTSIDE
# 2           N.Y. POLICE DEPT      MANHATTAN         28.0               NaN
# 3           N.Y. POLICE DEPT         QUEENS        105.0            INSIDE
# 5384153     N.Y. POLICE DEPT  STATEN ISLAND        122.0            INSIDE
# 5384154     N.Y. POLICE DEPT       BROOKLYN         61.0            INSIDE
# 5384155  N.Y. HOUSING POLICE      MANHATTAN          5.0            INSIDE
# 5384156  N.Y. HOUSING POLICE          BRONX         50.0            INSIDE
# 5384157     N.Y. POLICE DEPT       BROOKLYN         75.0            INSIDE
# 5384158     N.Y. POLICE DEPT       BROOKLYN         83.0            INSIDE
# 5384159     N.Y. POLICE DEPT         QUEENS        109.0            INSIDE
# 5384160     N.Y. POLICE DEPT          BRONX         41.0            INSIDE
# 5384161     N.Y. POLICE DEPT         QUEENS        109.0               NaN
# 5384162     N.Y. POLICE DEPT      MANHATTAN         30.0            INSIDE
# 5384163  N.Y. TRANSIT POLICE          BRONX         41.0               NaN
# 5384164     N.Y. POLICE DEPT         QUEENS        109.0          FRONT OF
# 5384165     N.Y. POLICE DEPT          BRONX         50.0            INSIDE
# 5384166     N.Y. POLICE DEPT       BROOKLYN         84.0            INSIDE
#
#                       PREM_TYP_DESC  X_COORD_CD  Y_COORD_CD   Latitude  \
# 0                    BAR/NIGHT CLUB   1007314.0    241257.0  40.828848
# 1                               NaN   1043991.0    193406.0  40.697338
# 2                             OTHER    999463.0    231690.0  40.802607
# 3                   RESIDENCE-HOUSE   1060183.0    177862.0  40.654549
# 4                             OTHER    987606.0    208148.0  40.738002
# 5                        DRUG STORE    996149.0    181562.0  40.665023
# 6                            STREET    987373.0    201662.0  40.720200
# 7                            STREET   1009041.0    247401.0  40.845707
# 8            RESIDENCE - APT. HOUSE   1014154.0    251416.0  40.856711
# 9                        DRUG STORE    994327.0    218211.0  40.765618
# 10                        FAST FOOD   1014216.0    238784.0  40.822040
# 11                 RESTAURANT/DINER    988113.0    206263.0  40.732828
# 12                           STREET    987215.0    215403.0  40.757916
# 13                           STREET    987215.0    215403.0  40.757916
# 14                           STREET   1004325.0    174113.0  40.644562
# 15                   BAR/NIGHT CLUB   1044662.0    197327.0  40.708096
# 16                 RESTAURANT/DINER    993034.0    214414.0  40.755197
# 17           RESIDENCE - APT. HOUSE   1014139.0    251858.0  40.857924
# 18           RESIDENCE - APT. HOUSE    993932.0    160170.0  40.606309
# 19              DRY CLEANER/LAUNDRY   1022298.0    186863.0  40.679499
# 20                           STREET    995387.0    178144.0  40.655642
# 21                           STREET   1012629.0    212283.0  40.749307
# 22           RESIDENCE - APT. HOUSE   1018309.0    183847.0  40.671237
# 23                  PUBLIC BUILDING   1008202.0    179835.0  40.660258
# 24                 RESTAURANT/DINER    992099.0    152792.0  40.586060
# 25                  RESIDENCE-HOUSE    978368.0    169905.0  40.633033
# 26                           STREET   1014100.0    183318.0  40.669800
# 27       RESIDENCE - PUBLIC HOUSING    998273.0    193029.0  40.696494
# 28                           STREET    940334.0    166826.0  40.624475
# 29           RESIDENCE - APT. HOUSE   1009069.0    244907.0  40.838862
# ...                             ...         ...         ...        ...
# 5384137      RESIDENCE - APT. HOUSE   1008394.0    221090.0  40.773493
# 5384166 -73.980416  (40.683616638, -73.980416007)       100.0        90.0
#
# [5384167 rows x 20 columns]

# %%
copy = list(dataset)
len(copy)
# Out:
# 20

# %%
def splitDataset(dataset, splitRatio):
	trainSize = int(len(dataset) * splitRatio)
	trainSet = []
	copy = list(dataset)
	while len(trainSet) < trainSize and len(copy)!= 0:
		index = random.randrange(len(copy))
		trainSet.append(copy.pop(index))
	return [trainSet, copy]

def separateByClass(dataset):
	separated = {}
	for i in range(len(dataset)):
		vector = dataset[i]
		if (vector[-1] not in separated):
			separated[vector[-1]] = []
		separated[vector[-1]].append(vector)
	return separated

def mean(numbers):
	return sum(numbers)/float(len(numbers))

def stdev(numbers):
	avg = mean(numbers)
	variance = sum([pow(x-avg,2) for x in numbers])/float(len(numbers)-1)
	return math.sqrt(variance)

def summarize(dataset):
	summaries = [(mean(attribute), stdev(attribute)) for attribute in zip(*dataset)]
	del summaries[-1]
	return summaries

def summarizeByClass(dataset):
	separated = separateByClass(dataset)
	summaries = {}
	for classValue, instances in separated.iteritems():
		summaries[classValue] = summarize(instances)
	return summaries

def calculateProbability(x, mean, stdev):
	exponent = math.exp(-(math.pow(x-mean,2)/(2*math.pow(stdev,2))))
	return (1 / (math.sqrt(2*math.pi) * stdev)) * exponent

def calculateClassProbabilities(summaries, inputVector):
	probabilities = {}
	for classValue, classSummaries in summaries.iteritems():
		probabilities[classValue] = 1
		for i in range(len(classSummaries)):
			mean, stdev = classSummaries[i]
			x = inputVector[i]
			probabilities[classValue] *= calculateProbability(x, mean, stdev)
	return probabilities
			
def predict(summaries, inputVector):
	probabilities = calculateClassProbabilities(summaries, inputVector)
	bestLabel, bestProb = None, -1
	for classValue, probability in probabilities.iteritems():
		if bestLabel is None or probability > bestProb:
			bestProb = probability
			bestLabel = classValue
	return bestLabel

def getPredictions(summaries, testSet):
	predictions = []
	for i in range(len(testSet)):
		result = predict(summaries, testSet[i])
		predictions.append(result)
	return predictions

def getAccuracy(testSet, predictions):
	correct = 0
	for i in range(len(testSet)):
		if testSet[i][-1] == predictions[i]:
			correct += 1
	return (correct/float(len(testSet))) * 100.0

def main():
	splitRatio = 0.67

	trainingSet, testSet = splitDataset(dataset, splitRatio)
	print('Split {0} rows into train={1} and test={2} rows').format(len(dataset), len(trainingSet), len(testSet))
	# prepare model
	summaries = summarizeByClass(trainingSet)
	# test model
	predictions = getPredictions(summaries, testSet)
	accuracy = getAccuracy(testSet, predictions)
	print('Accuracy: {0}%').format(accuracy)
    
main()
# Out:
# Split {0} rows into train={1} and test={2} rows
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-cbd2b0a48fe3> in <module>()
#      86         print('Accuracy: {0}%').format(accuracy)
#      87
# ---> 88 main()
#
# <ipython-input-24-cbd2b0a48fe3> in main()
#      78
#      79         trainingSet, testSet = splitDataset(dataset, splitRatio)
# ---> 80         print('Split {0} rows into train={1} and test={2} rows').format(len(dataset), len(trainingSet), len(testSet))
#      81         # prepare model
#      82         summaries = summarizeByClass(trainingSet)
#
# AttributeError: 'NoneType' object has no attribute 'format'
